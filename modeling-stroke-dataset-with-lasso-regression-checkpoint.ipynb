# %%
from datetime import datetime
import os
import pandas as pd
import numpy as np
from sklearn.linear_model import LassoCV
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error, roc_auc_score
import joblib
import matplotlib.pyplot as plt
from category_encoders.leave_one_out import LeaveOneOutEncoder
from sklearn.preprocessing import StandardScaler
from scipy import special

def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        tmin, tsec = divmod((datetime.now() - start_time).total_seconds(), 60)
        print(" Time taken: %i minutes and %s seconds." % (tmin, round(tsec, 2)))


DATA_TRAIN_PATH = os.path.join('data', 'train.csv')
DATA_TEST_PATH = os.path.join('data', 'test.csv')


def load_data(path_train=DATA_TRAIN_PATH, path_test=DATA_TEST_PATH):
    train_loader = pd.read_csv(path_train)
    train = train_loader.drop(["stroke", "id"], axis=1)
    features = train.columns.tolist()
    print("\n Train dataset shape:", train.shape)
    train_labels = train_loader["stroke"].values
    train_ids = train_loader["id"].values

    test_loader = pd.read_csv(path_test)
    test = test_loader[features]
    print(" Whole test dataset shape:", test.shape)
    test_ids = test_loader["id"].values

    return train, train_labels, train_ids, features, test, test_ids


if __name__ == "__main__":

    # We will do repeated K-fold cross-validation
    folds = 10
    repeats = 10
    # For historic reasons I use one of these 3 seeds
    seeds = [6772, 6659, 7622]

    # Load data set and target values
    start_time = timer(None)
    print("\n# Reading and Processing Data")
    X_train, y, train_ids, features, X_test, test_ids = load_data()

    all_cols = features
    cols_cat = [
        "gender",
        "ever_married",
        "work_type",
        "Residence_type",
        "smoking_status",
    ]
    num_features = [col for col in all_cols if col not in cols_cat]
# Out:
# # Reading and Processing Data
#
#  Train dataset shape: (15304, 10)
#  Whole test dataset shape: (10204, 10)

# %% [markdown]
# Like most generalized linear models, Lasso works only with numerical features and does not tolerate missing values. That means we have to toss out the categorical features, or convert them to numbers. We will do the latter. Didn't check whether features are normally distributed, but it doesn't hurt to standardize them.

# %%
print("\n Encoding categorical variables ...")
# sigma=0.05 injects a bit of noise so we don't overfit
ce = LeaveOneOutEncoder(cols=cols_cat, random_state=2022, sigma=0.05, verbose=1)
X_train = ce.fit_transform(X_train, y)
X_test = ce.transform(X_test)
print("\n Train Set Matrix Dimensions: %d x %d" % (X_train.shape[0], X_train.shape[1]))
print(" Test Set Matrix Dimensions: %d x %d" % (X_test.shape[0], X_test.shape[1]))

print(
    " Potential NaN or Inf values in train data:  ",
    np.isnan(X_train[features].values).any(),
    "  ",
    np.isinf(X_train[features].values).any(),
)
print(
    " Potential NaN or Inf values in test data:  ",
    np.isnan(X_test[features].values).any(),
    "  ",
    np.isinf(X_test[features].values).any(),
)
timer(start_time)

scaler = StandardScaler()
scaler.fit(X_train[features].values)
X_train[features] = scaler.transform(X_train[features].values)
joblib.dump(scaler, "StandardScaler_Lasso-01-v1.joblib")
# scaler = joblib.load('StandardScaler_Lasso-01-v1.joblib')
X_test[features] = scaler.transform(X_test[features].values)
# Out:
#  Encoding categorical variables ...
#
#  Train Set Matrix Dimensions: 15304 x 10
#  Test Set Matrix Dimensions: 10204 x 10
#  Potential NaN or Inf values in train data:   False    False
#  Potential NaN or Inf values in test data:   False    False
#  Time taken: 0 minutes and 0.18 seconds.

# %% [markdown]
# All rigth, now we have all-numerical data. Time to set up cross-validation and let Lasso rip.

# %%
rkf_grid = list(
    RepeatedKFold(n_splits=folds, n_repeats=repeats, random_state=seeds[0]).split(
        X_train, y
    )
)
start_time = timer(None)
# Run Lasso cross-validation to determine coefficient alpha and the intercept
# Doing repeated CV to test many different folds and avoid overfitting
print("\n Running Lasso:")
model_llcv = LassoCV(
    precompute="auto",
    fit_intercept=True,
    #normalize=False,
    max_iter=1000,
    verbose=False,
    eps=1e-04,
    cv=rkf_grid,
    n_alphas=1000,
    n_jobs=8,
)
model_llcv.fit(X_train, y)
joblib.dump(model_llcv, "Stroke_Lasso-01-v1.joblib")
#    model_llcv = joblib.load('Stroke_Lasso-01-v1.joblib')
print(" Best alpha value: %.10f" % model_llcv.alpha_)
print(" Intercept: %.10f" % model_llcv.intercept_)
print(" LassoCV score: %.10f" % model_llcv.score(X_train, y))
# Out:
#  Running Lasso:
#  Best alpha value: 0.0002039691
#  Intercept: 0.0412963931
#  LassoCV score: 0.1058680019

# %% [markdown]
# We have our model parameters. The value of alpha is critical, as we don't want to over- or under-fit the model. Large alpha values will make most feature coefficents be zero, and the model will be very simple and likely under-fitted. When alpha is 0, we have linear regression which means no regularization and stronger potential for over-fitting.
#
# Let's do a quick test to see what kind of score we can expect.

# %%
RMSE_nocv = np.sqrt(mean_squared_error(y, model_llcv.predict(X_train)))
AUC_nocv = roc_auc_score(y, model_llcv.predict(X_train))
print("\n Non cross-validated LassoCV RMSE: %.6f" % RMSE_nocv)
print(" Non cross-validated AUC: %.6f" % AUC_nocv)
# Out:
#  Non cross-validated LassoCV RMSE: 0.188148
#  Non cross-validated AUC: 0.872729

# %% [markdown]
# Now we run this on even larger number of different folds (10 folds repeated 10 times). The idea again is to avoid overfitting and guard against uneven data distributions within folds, as we will average every single point 10 times in out-of-fold fashion. We will have to keep track of how many times each point has been predicted and divide its sum by the number of predictions.

# %%
cv_sum = 0
cv_sum_auc = 0
pred = []
fpred = []
avreal = y
avpred = np.zeros(X_train.shape[0])
avpred_count = np.zeros(X_train.shape[0])
idpred = train_ids

train_time = timer(None)
repeats = 10
rkf_grid = list(
    RepeatedKFold(n_splits=folds, n_repeats=repeats, random_state=seeds[0]).split(
        X_train, y
    )
)

for i, (train_index, val_index) in enumerate(rkf_grid):
    fold_time = timer(None)
    print("\n Fold %02d" % (i + 1))
    Xtrain, Xval = X_train.loc[train_index], X_train.loc[val_index]
    ytrain, yval = y[train_index], y[val_index]

    scores_val = model_llcv.predict(Xval)
    corr_val = np.sqrt(mean_squared_error(yval, scores_val))
    corr_val_auc = roc_auc_score(yval, scores_val)
    print(" Fold %02d RMSE: %.6f" % ((i + 1), corr_val))
    print(" Fold %02d AUC: %.6f" % ((i + 1), corr_val_auc))
    y_pred = model_llcv.predict(X_test)
    timer(fold_time)

    avpred[val_index] += scores_val
    avpred_count[val_index] += 1
    if i > 0:
        fpred = pred + y_pred
    else:
        fpred = y_pred
    pred = fpred
    cv_sum = cv_sum + corr_val
    cv_sum_auc = cv_sum_auc + corr_val_auc

timer(train_time)

cv_score = cv_sum / (folds * repeats)
cv_score_auc = cv_sum_auc / (folds * repeats)
avpred = avpred / avpred_count
oof_corr = np.sqrt(mean_squared_error(avreal, avpred))
oof_corr_auc = roc_auc_score(avreal, avpred)
print("\n Average RMSE: %.6f" % cv_score)
print(" Out-of-fold RMSE: %.6f" % oof_corr)
print(" Average AUC: %.6f" % cv_score_auc)
print(" Out-of-fold AUC: %.6f" % oof_corr_auc)
score = str(round(oof_corr_auc, 6)).replace(".", "")
mpred = pred / (folds * repeats)

now = datetime.now()
# Not really necessary, but applying sigmoid function here so all predictions map to [0,1] range
oof_result = pd.DataFrame(avreal, columns=["stroke"])
oof_result["prediction"] = special.expit(avpred)
oof_result["id"] = idpred
oof_result = oof_result[["id", "stroke", "prediction"]]
sub_file = (
    "train_OOF_10_by_10x-Lasso_"
    + score
    + "_"
    + str(now.strftime("%Y-%m-%d-%H-%M"))
    + ".csv"
)
print("\n Writing out-of-fold train file::  %s" % sub_file)
oof_result.to_csv(sub_file, index=False, float_format="%.6f")

# Not really necessary, but applying sigmoid function here so all predictions map to [0,1] range
result = pd.DataFrame(special.expit(mpred), columns=["stroke"])
result["id"] = test_ids
result = result[["id", "stroke"]]
print("\n First 10 lines of your prediction:")
print(result.head(10))
sub_file = (
    "test_10_by_10x-Lasso_" + score + "_" + str(now.strftime("%Y-%m-%d-%H-%M")) + ".csv"
)
print("\n Writing submission file::  %s" % sub_file)
result.to_csv(sub_file, index=False, float_format="%.6f")
result.to_csv("submission.csv", index=False, float_format="%.6f")
# Out:
#  Fold 01
#  Fold 01 RMSE: 0.186676
#  Fold 01 AUC: 0.875578
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 02
#  Fold 02 RMSE: 0.184444
#  Fold 02 AUC: 0.852708
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 03
#  Fold 03 RMSE: 0.186468
#  Fold 03 AUC: 0.862317
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 04
#  Fold 04 RMSE: 0.191557
#  Fold 04 AUC: 0.872655
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 05
#  Fold 05 RMSE: 0.187535
#  Fold 05 AUC: 0.887342
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 06
#  Fold 06 RMSE: 0.187056
#  Fold 06 AUC: 0.827574
#  Time taken: 0 minutes and 0.03 seconds.
#
#  Fold 07
#  Fold 07 RMSE: 0.202418
#  Fold 07 AUC: 0.876374
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 08
#  Fold 08 RMSE: 0.181962
#  Fold 08 AUC: 0.877842
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 09
#  Fold 09 RMSE: 0.185744
#  Fold 09 AUC: 0.892784
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 10
#  Fold 10 RMSE: 0.186871
#  Fold 10 AUC: 0.896420
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 11
#  Fold 11 RMSE: 0.181294
#  Fold 11 AUC: 0.905271
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 12
#  Fold 12 RMSE: 0.200643
#  Fold 12 AUC: 0.862215
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 13
#  Fold 13 RMSE: 0.189100
#  Fold 13 AUC: 0.866301
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 14
#  Fold 14 RMSE: 0.192438
#  Fold 14 AUC: 0.829062
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 15
#  Fold 15 RMSE: 0.189753
#  Fold 15 AUC: 0.900967
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 16
#  Fold 16 RMSE: 0.190053
#  Fold 16 AUC: 0.849942
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 17
#  Fold 17 RMSE: 0.165376
#  Fold 17 AUC: 0.900426
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 18
#  Fold 18 RMSE: 0.173801
#  Fold 18 AUC: 0.827554
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 19
#  Fold 19 RMSE: 0.196317
#  Fold 19 AUC: 0.889612
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 20
#  Fold 20 RMSE: 0.199634
#  Fold 20 AUC: 0.884049
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 21
#  Fold 21 RMSE: 0.197093
#  Fold 21 AUC: 0.870389
#  Time taken: 0 minutes and 0.03 seconds.
#
#  Fold 22
#  Fold 22 RMSE: 0.183916
#  Fold 22 AUC: 0.857061
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 23
#  Fold 23 RMSE: 0.194764
#  Fold 23 AUC: 0.880182
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 24
#  Fold 24 RMSE: 0.196510
#  Fold 24 AUC: 0.864866
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 25
#  Fold 25 RMSE: 0.184515
#  Fold 25 AUC: 0.866654
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 26
#  Fold 26 RMSE: 0.171253
#  Fold 26 AUC: 0.856581
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 27
#  Fold 27 RMSE: 0.206893
#  Fold 27 AUC: 0.871539
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 28
#  Fold 28 RMSE: 0.168201
#  Fold 28 AUC: 0.872090
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 29
#  Fold 29 RMSE: 0.181435
#  Fold 29 AUC: 0.897280
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 30
#  Fold 30 RMSE: 0.193345
#  Fold 30 AUC: 0.886014
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 31
#  Fold 31 RMSE: 0.186871
#  Fold 31 AUC: 0.866232
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 32
#  Fold 32 RMSE: 0.183518
#  Fold 32 AUC: 0.866961
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 33
#  Fold 33 RMSE: 0.188028
#  Fold 33 AUC: 0.871879
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 34
#  Fold 34 RMSE: 0.208176
#  Fold 34 AUC: 0.854753
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 35
#  Fold 35 RMSE: 0.180727
#  Fold 35 AUC: 0.917562
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 36
#  Fold 36 RMSE: 0.177442
#  Fold 36 AUC: 0.873245
#  Time taken: 0 minutes and 0.03 seconds.
#
#  Fold 37
#  Fold 37 RMSE: 0.189724
#  Fold 37 AUC: 0.826791
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 38
#  Fold 38 RMSE: 0.187163
#  Fold 38 AUC: 0.909982
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 39
#  Fold 39 RMSE: 0.192200
#  Fold 39 AUC: 0.893591
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 40
#  Fold 40 RMSE: 0.185975
#  Fold 40 AUC: 0.845395
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 41
#  Fold 41 RMSE: 0.195374
#  Fold 41 AUC: 0.844387
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 42
#  Fold 42 RMSE: 0.174631
#  Fold 42 AUC: 0.884112
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 43
#  Fold 43 RMSE: 0.200782
#  Fold 43 AUC: 0.882023
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 44
#  Fold 44 RMSE: 0.186022
#  Fold 44 AUC: 0.881755
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 45
#  Fold 45 RMSE: 0.187029
#  Fold 45 AUC: 0.851543
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 46
#  Fold 46 RMSE: 0.181953
#  Fold 46 AUC: 0.883691
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 47
#  Fold 47 RMSE: 0.193252
#  Fold 47 AUC: 0.878404
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 48
#  Fold 48 RMSE: 0.192212
#  Fold 48 AUC: 0.855626
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 49
#  Fold 49 RMSE: 0.182535
#  Fold 49 AUC: 0.868566
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 50
#  Fold 50 RMSE: 0.186311
#  Fold 50 AUC: 0.896615
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 51
#  Fold 51 RMSE: 0.196977
#  Fold 51 AUC: 0.884160
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 52
#  Fold 52 RMSE: 0.189559
#  Fold 52 AUC: 0.871901
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 53
#  Fold 53 RMSE: 0.184768
#  Fold 53 AUC: 0.873001
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 54
#  Fold 54 RMSE: 0.206318
#  Fold 54 AUC: 0.866015
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 55
#  Fold 55 RMSE: 0.187523
#  Fold 55 AUC: 0.890911
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 56
#  Fold 56 RMSE: 0.187500
#  Fold 56 AUC: 0.877362
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 57
#  Fold 57 RMSE: 0.176673
#  Fold 57 AUC: 0.850196
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 58
#  Fold 58 RMSE: 0.180753
#  Fold 58 AUC: 0.857664
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 59
#  Fold 59 RMSE: 0.191134
#  Fold 59 AUC: 0.861297
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 60
#  Fold 60 RMSE: 0.178359
#  Fold 60 AUC: 0.890187
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 61
#  Fold 61 RMSE: 0.187845
#  Fold 61 AUC: 0.864303
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 62
#  Fold 62 RMSE: 0.178031
#  Fold 62 AUC: 0.853289
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 63
#  Fold 63 RMSE: 0.185073
#  Fold 63 AUC: 0.860662
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 64
#  Fold 64 RMSE: 0.166469
#  Fold 64 AUC: 0.873876
#  Time taken: 0 minutes and 0.03 seconds.
#
#  Fold 65
#  Fold 65 RMSE: 0.193025
#  Fold 65 AUC: 0.883066
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 66
#  Fold 66 RMSE: 0.175949
#  Fold 66 AUC: 0.893917
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 67
#  Fold 67 RMSE: 0.191915
#  Fold 67 AUC: 0.876639
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 68
#  Fold 68 RMSE: 0.197741
#  Fold 68 AUC: 0.855117
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 69
#  Fold 69 RMSE: 0.200965
#  Fold 69 AUC: 0.891187
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 70
#  Fold 70 RMSE: 0.201304
#  Fold 70 AUC: 0.871937
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 71
#  Fold 71 RMSE: 0.187160
#  Fold 71 AUC: 0.885710
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 72
#  Fold 72 RMSE: 0.178430
#  Fold 72 AUC: 0.880180
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 73
#  Fold 73 RMSE: 0.190557
#  Fold 73 AUC: 0.872285
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 74
#  Fold 74 RMSE: 0.187788
#  Fold 74 AUC: 0.852698
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 75
#  Fold 75 RMSE: 0.171274
#  Fold 75 AUC: 0.895519
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 76
#  Fold 76 RMSE: 0.186706
#  Fold 76 AUC: 0.890401
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 77
#  Fold 77 RMSE: 0.197357
#  Fold 77 AUC: 0.877719
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 78
#  Fold 78 RMSE: 0.203467
#  Fold 78 AUC: 0.845421
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 79
#  Fold 79 RMSE: 0.184113
#  Fold 79 AUC: 0.818024
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 80
#  Fold 80 RMSE: 0.192652
#  Fold 80 AUC: 0.904744
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 81
#  Fold 81 RMSE: 0.188582
#  Fold 81 AUC: 0.878361
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 82
#  Fold 82 RMSE: 0.181449
#  Fold 82 AUC: 0.900748
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 83
#  Fold 83 RMSE: 0.175725
#  Fold 83 AUC: 0.875661
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 84
#  Fold 84 RMSE: 0.201126
#  Fold 84 AUC: 0.876675
#  Time taken: 0 minutes and 0.0 seconds.
#
#  Fold 85
#  Fold 85 RMSE: 0.190148
#  Fold 85 AUC: 0.819856
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 86
#  Fold 86 RMSE: 0.186296
#  Fold 86 AUC: 0.860327
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 87
#  Fold 87 RMSE: 0.214641
#  Fold 87 AUC: 0.857253
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 88
#  Fold 88 RMSE: 0.172997
#  Fold 88 AUC: 0.895875
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 89
#  Fold 89 RMSE: 0.178240
#  Fold 89 AUC: 0.899339
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 90
#  Fold 90 RMSE: 0.188543
#  Fold 90 AUC: 0.868093
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 91
#  Fold 91 RMSE: 0.197427
#  Fold 91 AUC: 0.860330
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 92
#  Fold 92 RMSE: 0.178559
#  Fold 92 AUC: 0.881906
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 93
#  Fold 93 RMSE: 0.190830
#  Fold 93 AUC: 0.839778
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 94
#  Fold 94 RMSE: 0.191877
#  Fold 94 AUC: 0.877608
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 95
#  Fold 95 RMSE: 0.174017
#  Fold 95 AUC: 0.904900
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 96
#  Fold 96 RMSE: 0.169357
#  Fold 96 AUC: 0.867023
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 97
#  Fold 97 RMSE: 0.210743
#  Fold 97 AUC: 0.870306
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 98
#  Fold 98 RMSE: 0.198622
#  Fold 98 AUC: 0.880773
#  Time taken: 0 minutes and 0.02 seconds.
#
#  Fold 99
#  Fold 99 RMSE: 0.176846
#  Fold 99 AUC: 0.866008
#  Time taken: 0 minutes and 0.01 seconds.
#
#  Fold 100
#  Fold 100 RMSE: 0.189207
#  Fold 100 AUC: 0.880382
#  Time taken: 0 minutes and 0.02 seconds.
#  Time taken: 0 minutes and 1.41 seconds.
#
#  Average RMSE: 0.187896
#  Out-of-fold RMSE: 0.188148
#  Average AUC: 0.872434
#  Out-of-fold AUC: 0.872729
#
#  Writing out-of-fold train file::  train_OOF_10_by_10x-Lasso_0872729_2023-01-21-20-07.csv
#
#  First 10 lines of your prediction:
#       id    stroke
# 0  15304  0.518045
# 1  15305  0.543964
# 2  15306  0.499221
# 3  15307  0.510473
# 4  15308  0.500543
# 5  15309  0.504025
# 6  15310  0.506301
# 7  15311  0.526312
# 8  15312  0.499614
# 9  15313  0.514553
#
#  Writing submission file::  test_10_by_10x-Lasso_0872729_2023-01-21-20-07.csv

# %% [markdown]
# We are done with predictions. Without any fancy setup or parameter tuning, this will score ~0.87 on public LB.
#
# Let's see what features Lasso selected from the whole group. Features with low coefficients contribute less to the final prediction. The absolute value of each feature coefficient is roughly proportional to its importance.

# %%
coef = pd.DataFrame(model_llcv.coef_, columns=["LassoCV_score"])
coef["Feature"] = features
coef["Relative score"] = coef["LassoCV_score"] / coef["LassoCV_score"].sum()
coef = coef.sort_values("Relative score", ascending=False)
coef = coef[["Feature", "LassoCV_score", "Relative score"]]
coef.to_csv("feature_importance_LassoCV.csv", index=False, float_format="%.6f")
coef.plot(kind="barh", x="Feature", y="LassoCV_score", legend=False, figsize=(6, 12))
plt.title("Features Coefficients")
plt.xlabel("LassoCV score")
plt.savefig(
    "feature_importance_Lasso-01-v1.png",
    bbox_inches="tight",
    pad_inches=0.25,
    dpi=150,
)
plt.show()
